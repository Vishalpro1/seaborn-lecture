# %%
# !pip install seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
# Relation Plots:
  # ----> 2 columns statistical relationship


    # 1) Scatter plot
    # 2) Line plot

# %%
# Loading data

ploty_tips = px.data.tips()

# %%
ploty_tips.sample(5)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 80        19.44  3.00    Male    Yes  Thur   Lunch     2
# 44        30.40  5.60    Male     No   Sun  Dinner     4
# 112       38.07  4.00    Male     No   Sun  Dinner     3
# 171       15.81  3.16    Male    Yes   Sat  Dinner     2
# 162       16.21  2.00  Female     No   Sun  Dinner     3

# %%
tips_data = sns.load_dataset('tips')

# %%
tips_data.shape
# Out:
# (244, 7)

# %%
tips_data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Scatter Plot

    # ---> figure level function
    # ---> axis level function

# %%
# --------> axis level function


sns.scatterplot(data = tips_data, x = "total_bill", y = "tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# figure level function

# %%
# figure level function

sns.relplot(data = tips_data, x = "total_bill", y = "tip", kind = "scatter")

# %%
# aixs level function

sns.scatterplot(data = tips_data, x = "total_bill", y = "tip", hue = "sex")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# figure level function

sns.relplot(data = tips_data, x = "total_bill", y = "tip", kind = "scatter", hue = "sex")

# %%
# aixs level function

sns.scatterplot(data = tips_data, x = "total_bill", y = "tip", hue = "sex", style = "time")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
tips_data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# figure level function

sns.relplot(data = tips_data, x = "total_bill", y = "tip", kind = "scatter", hue = "sex", style = "time")

# %%
# aixs level function

sns.scatterplot(data = tips_data,
                x = "total_bill", y = "tip", hue = "sex",
                style = "time", size = "size")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
tips_data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# figure level function

sns.relplot(data = tips_data, x = "total_bill",
            y = "tip", kind = "scatter", hue = "sex",
            style = "time", size = "size")

# %%
# Change theam

# aixs level function

sns.scatterplot(data = tips_data,
                x = "total_bill", y = "tip", hue = "sex",
                style = "time", size = "size", palette = "deep")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# Change theam

# aixs level function

sns.scatterplot(data = tips_data,
                x = "total_bill", y = "tip", hue = "sex",
                style = "time", size = "size", palette = "muted")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# Change theam

# aixs level function

sns.scatterplot(data = tips_data,
                x = "total_bill", y = "tip", hue = "sex",
                style = "time", size = "size", palette = "dark")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# Change theam

# aixs level function

sns.scatterplot(data = tips_data,
                x = "total_bill", y = "tip", hue = "sex",
                style = "time", size = "size", palette = "Set1")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# Change theam

# aixs level function

sns.scatterplot(data = tips_data,
                x = "total_bill", y = "tip", hue = "sex",
                style = "time", size = "size", palette = "Set3")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# Change theam

# aixs level function

sns.scatterplot(data = tips_data,
                x = "total_bill", y = "tip", hue = "sex",
                style = "time", size = "size", palette = "Paired")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# Change theam

# aixs level function

sns.scatterplot(data = tips_data,
                x = "total_bill", y = "tip", hue = "sex",
                style = "time", size = "size", palette = "Accent")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# Change theam

# aixs level function

sns.scatterplot(data = tips_data,
                x = "total_bill", y = "tip", hue = "sex",
                style = "time", size = "size", palette = "dark", legend = False)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# Change theam

# aixs level function

sns.scatterplot(ief")data = tips_data,
                x = "total_bill", y = "tip", hue = "sex",
                style = "time", size = "size", palette = "dark", legend = "br
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# Line plot
      # mostly use when we have somethone---> time series

# %%
# Dataset

gap_data = px.data.gapminder()
gap_data
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
gap_data.shape
# Out:
# (1704, 8)

# %%
gap_data
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
gap_data["year"].value_counts()
# Out:
# year
# 1952    142
# 1957    142
# 1962    142
# 1967    142
# 1972    142
# 1977    142
# 1982    142
# 1987    142
# 1992    142
# 1997    142
# 2002    142
# 2007    142
# Name: count, dtype: int64

# %%
india_data = gap_data[gap_data["country"] == "India"]

# %%
india_data
# Out:
#     country continent  year  lifeExp         pop    gdpPercap iso_alpha  \
# 696   India      Asia  1952   37.373   372000000   546.565749       IND
# 697   India      Asia  1957   40.249   409000000   590.061996       IND
# 698   India      Asia  1962   43.605   454000000   658.347151       IND
# 699   India      Asia  1967   47.193   506000000   700.770611       IND
# 700   India      Asia  1972   50.651   567000000   724.032527       IND
# 701   India      Asia  1977   54.208   634000000   813.337323       IND
# 702   India      Asia  1982   56.596   708000000   855.723538       IND
# 703   India      Asia  1987   58.553   788000000   976.512676       IND
# 704   India      Asia  1992   60.223   872000000  1164.406809       IND
# 705   India      Asia  1997   61.765   959000000  1458.817442       IND
# 706   India      Asia  2002   62.879  1034172547  1746.769454       IND
# 707   India      Asia  2007   64.698  1110396331  2452.210407       IND
#
#      iso_num
# 696      356
# ...

# %%
# axis level function

sns.lineplot(data = india_data, x = "year", y = "lifeExp")
# Out:
# <Axes: xlabel='year', ylabel='lifeExp'>

# %%
# fig lebel function

sns.relplot(data = india_data, x = "year", y = "lifeExp", kind = "line")

# %%
gap_data
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
gap_data["country"].value_counts()
# Out:
# country
# Afghanistan           12
# Albania               12
# Algeria               12
# Angola                12
# Argentina             12
#                       ..
# Vietnam               12
# West Bank and Gaza    12
# Yemen, Rep.           12
# Zambia                12
# Zimbabwe              12
# Name: count, Length: 142, dtype: int64

# %%
gap_data[gap_data["country"].isin(["India", "Zambia", "Germany"])]
# Out:
#       country continent  year  lifeExp         pop     gdpPercap iso_alpha  \
# 564   Germany    Europe  1952   67.500    69145952   7144.114393       DEU
# 565   Germany    Europe  1957   69.100    71019069  10187.826650       DEU
# 566   Germany    Europe  1962   70.300    73739117  12902.462910       DEU
# 567   Germany    Europe  1967   70.800    76368453  14745.625610       DEU
# 568   Germany    Europe  1972   71.000    78717088  18016.180270       DEU
# 569   Germany    Europe  1977   72.500    78160773  20512.921230       DEU
# 570   Germany    Europe  1982   73.800    78335266  22031.532740       DEU
# 571   Germany    Europe  1987   74.847    77718298  24639.185660       DEU
# 572   Germany    Europe  1992   76.070    80597764  26505.303170       DEU
# 573   Germany    Europe  1997   77.340    82011073  27788.884160       DEU
# 574   Germany    Europe  2002   78.670    82350671  30035.801980       DEU
# ...

# %%
cun_data = gap_data[gap_data["country"].isin(["India", "Zambia", "Germany"])]

cun_data.shape
# Out:
# (36, 8)

# %%
sns.lineplot(data = cun_data, x= "year", y = "lifeExp", hue = "country")
# Out:
# <Axes: xlabel='year', ylabel='lifeExp'>

# %%
# Fig level fun

# %%
sns.relplot(kind = "line", data = cun_data, x = "year", y = "lifeExp", hue = "country")

# %%
sns.relplot(kind = "line", data = cun_data, x = "year", y = "lifeExp", hue = "country", style = "continent")

# %%
cun_data
# Out:
#       country continent  year  lifeExp         pop     gdpPercap iso_alpha  \
# 564   Germany    Europe  1952   67.500    69145952   7144.114393       DEU
# 565   Germany    Europe  1957   69.100    71019069  10187.826650       DEU
# 566   Germany    Europe  1962   70.300    73739117  12902.462910       DEU
# 567   Germany    Europe  1967   70.800    76368453  14745.625610       DEU
# 568   Germany    Europe  1972   71.000    78717088  18016.180270       DEU
# 569   Germany    Europe  1977   72.500    78160773  20512.921230       DEU
# 570   Germany    Europe  1982   73.800    78335266  22031.532740       DEU
# 571   Germany    Europe  1987   74.847    77718298  24639.185660       DEU
# 572   Germany    Europe  1992   76.070    80597764  26505.303170       DEU
# 573   Germany    Europe  1997   77.340    82011073  27788.884160       DEU
# 574   Germany    Europe  2002   78.670    82350671  30035.801980       DEU
# ...

# %%
cun_data = gap_data[gap_data["country"].isin(["India", "Zambia", "Germany", "Afghanistan", "Zimbabwe"])]

cun_data.shape
# Out:
# (60, 8)

# %%
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
sns.relplot(kind = "line", data = cun_data, x = "year", y = "lifeExp", hue = "country", style = "continent")

# %%
sns.relplot(kind = "line", data = cun_data, x = "year", y = "lifeExp",
            hue = "country", style = "continent", size = "continent")

# %%
gap_data
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...
